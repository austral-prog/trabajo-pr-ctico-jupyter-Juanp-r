# %% [markdown]
# # Assignment
#
# The assignment will require you to complete cells, create new ones, and move around some cells. You need to familiarize yourself with the Jupyter notebook interface. You can find a tutorial [here](https://www.dataquest.io/blog/jupyter-notebook-tutorial/).

# %% [markdown]
# # [EXERCISE 1]
# ## Juan Ignacio Prieto Ryser jiprietoryser@mail.austral.edu.ar
# ![image.png](attachment:8483224c-5be7-4a5d-9d12-4f68f0b89ea8.png)
#
# un perro cachorro mirando a la camara. me gustan los perros

# %% [markdown]
# ---

# %% [markdown]
# # EXERCISE 5

# %%
a=3
b=7

# %% [markdown]
# suma

# %%
a+b

# %% [markdown]
# resta

# %%
b-a

# %% [markdown]
# multiplicacion

# %%
a*b

# %% [markdown]
# division

# %%
b/a
